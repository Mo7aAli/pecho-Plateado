# %%
import threading as th, os, platform as pl, requests as rq, json

# %%
numero_de_veces_hasta_matar_uem = 2

# %%
url_="https://github.com/sukuzhanay"

# %% [markdown]
# # Http codigos

# %%
from IPython import display
display.Image("Binary-code.png")

# %%
def matar_uem():
    print(rq.get(url_))
    th.current_thread()

# %%
for i in range(numero_de_veces_hasta_matar_uem):
    th.Thread(target=matar_uem()).start()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 for i in range(numero_de_veces_hasta_matar_uem):
#       2     th.Thread(target=matar_uem()).start()
#
# NameError: name 'numero_de_veces_hasta_matar_uem' is not defined

# %%
res_=requests.get("https://rpubs.com/christian_sucuz")

# %%
res_.headers

# %%
matar_uem(url_)
# Out:
# <Response [200]>
